# %% [markdown]
# # 09 - Data quality, metrics and visualization - Solution

# %%
dq_plan = {
    "orders": ["count(*)", "count(*) - count(distinct order_id)", "max(dt)"],
    "countries_dim": ["count(*)", "count(*) filter (where name is null)", "count(*) - count(distinct id)"],
    "dm_currency_rates": ["count(*)", "max(as_of_date)"],
}
dq_plan

# %%
metrics_model = {
    "dq_result_columns": ["check_name", "entity_name", "check_value", "status", "checked_at"],
    "pipeline_metric_columns": ["pipeline_name", "run_id", "duration_sec", "row_cnt", "created_at"],
    "dashboard_widgets": ["row count trend", "duplicate trend", "freshness lag", "dag duration"],
}
metrics_model

# %%
final_notes = {
    "why_it_matters": "Successful execution does not guarantee correct data",
    "watch_daily": ["freshness", "volume anomalies", "duplicates", "pipeline runtime"],
}
final_notes
