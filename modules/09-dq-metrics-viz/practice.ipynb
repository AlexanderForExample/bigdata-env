# %% [markdown]
# # 09 - Data quality, metrics and visualization
#
# Цель: формализовать DQ-checks, собрать runtime metrics и подготовить материал для дашборда.

# %%
import pandas as pd

dq_dimensions = ["count", "null_rate", "duplicates", "freshness"]
dq_dimensions

# %% [markdown]
# ## Task A - Define checks

# %%
dq_matrix = {
    "table_1": {"count": "TODO", "null_rate": "TODO", "duplicates": "TODO", "freshness": "TODO"},
    "table_2": {"count": "TODO", "null_rate": "TODO", "duplicates": "TODO", "freshness": "TODO"},
}
dq_matrix

# %% [markdown]
# ## Task B - Store results

# %%
metrics_storage_design = {
    "dq_results_table": "TODO",
    "pipeline_metrics_table": "TODO",
    "dashboard_source": "TODO",
}
metrics_storage_design

# %% [markdown]
# ## Task C - Visualization plan

# %%
dashboard_widgets = [
    "TODO: row count by load_date",
    "TODO: null rate by critical column",
    "TODO: pipeline duration trend",
]
dashboard_widgets
