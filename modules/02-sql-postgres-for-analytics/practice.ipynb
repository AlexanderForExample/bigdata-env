# %% [markdown]
# # 02 - SQL in Postgres for analytics
#
# Цель: построить аналитические SQL-запросы и витрины по учебным таблицам в Postgres.

# %%
import os
import pandas as pd
from sqlalchemy import create_engine, text

PG_URL = (
    f"postgresql+psycopg2://{os.getenv('PG_USER', 'postgres')}:{os.getenv('PG_PWD', 'postgres')}"
    f"@{os.getenv('PG_HOST', 'postgres-tgt')}:{os.getenv('PG_PORT', '5432')}/{os.getenv('PG_DB', 'postgres')}"
)
engine = create_engine(PG_URL)

# %% [markdown]
# ## Task A - Basic SQL

# %%
# TODO: посчитай количество строк в orders, products, users
# TODO: посчитай выручку по dt
# TODO: покажи 10 строк результата через pd.read_sql(...)

# %% [markdown]
# ## Task B - Build a mart
#
# Собери витрину продаж по дням и категориям через join и CTE.

# %%
# TODO: orders + products -> revenue by dt, category

# %% [markdown]
# ## Task C - Window functions
#
# Построй рейтинг товаров по выручке внутри категории.

# %%
# TODO: используй rank() over (partition by category order by revenue desc)

# %%
# TODO: добавь 2-3 проверки витрины: null, duplicates, suspicious totals
