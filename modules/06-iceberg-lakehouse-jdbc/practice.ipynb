# %% [markdown]
# # 06 - Iceberg lakehouse and JDBC integration
#
# Цель: спроектировать и подготовить сценарий `JDBC -> Spark -> Iceberg`.

# %%
JDBC_URL = "jdbc:postgresql://postgres-tgt:5432/postgres"
JDBC_PROPS = {
    "user": "postgres",
    "password": "postgres",
    "driver": "org.postgresql.Driver",
}
ICEBERG_TABLE = "local.db.sales_by_day"

# %% [markdown]
# ## Task A - Read source through JDBC

# %%
# TODO: создай SparkSession с Iceberg catalog
# TODO: прочитай orders через spark.read.jdbc(...)

# %% [markdown]
# ## Task B - Curated transform

# %%
# TODO: сгруппируй данные по dt или category и подготовь curated DataFrame

# %% [markdown]
# ## Task C - Write to Iceberg

# %%
# TODO: запиши результат в Iceberg table и проверь чтение через spark.table(...)

# %% [markdown]
# ## Note
#
# Если Iceberg catalog еще не поднят, используй этот ноутбук как дизайн и рабочий шаблон под будущую инфраструктуру.
