# %% [markdown]
# # 01 - HDFS and YARN fundamentals
#
# Цель: пройти путь `local -> HDFS -> Spark on YARN` и понять роли сервисов кластера.

# %% [markdown]
# ## Practice plan
#
# - проверить UI и роли сервисов
# - загрузить датасет в HDFS
# - прочитать данные Spark job'ом через YARN

# %%
MODULE_NAME = "01-hdfs-yarn-fundamentals"
SERVICE_URLS = {
    "namenode_ui": "http://localhost:9870",
    "yarn_ui": "http://localhost:8088",
    "spark_ui": "http://localhost:8080",
}
SERVICE_URLS

# %% [markdown]
# ## Task A - Cluster roles
#
# Заполни роли сервисов и раздели их на storage/compute.

# %%
cluster_roles = {
    "storage": ["TODO"],
    "compute": ["TODO"],
    "namenode": "TODO",
    "datanode": "TODO",
    "resourcemanager": "TODO",
    "nodemanager": "TODO",
}
cluster_roles

# %% [markdown]
# ## Task B - HDFS commands
#
# Выполни команды из контейнера со Spark/Hadoop CLI.

# %%
hdfs_commands = [
    "hdfs dfs -mkdir -p /data/course/orders",
    "hdfs dfs -put -f /workspace/dataset/orders.csv /data/course/orders/",
    "hdfs dfs -ls /data/course/orders",
    "hdfs dfs -du -h /data/course/orders",
]
hdfs_commands

# %%
# TODO: вставь сюда результаты команд или выполни их прямо в ноутбуке через !hdfs dfs ...

# %% [markdown]
# ## Task C - Spark on YARN

# %%
# TODO: создай SparkSession с master='yarn'
# TODO: прочитай hdfs://namenode:8020/data/course/orders/orders.csv
# TODO: покажи count(), printSchema() и show(5)

# %% [markdown]
# ## Reflection
#
# Что хранит HDFS, а что делает YARN во время выполнения приложения?

# %%
reflection = {
    "hdfs": "TODO",
    "yarn": "TODO",
    "where_to_debug": "TODO",
}
reflection
