# %% [markdown]
# # 08 - Kafka streaming to Iceberg
#
# Цель: спроектировать поток `Kafka -> streaming consumer -> Iceberg` и подготовить каркас реализации.

# %% [markdown]
# ## Important note
#
# Kafka stack пока не оформлен как runnable minimal stack в проекте. Но ноутбук уже можно использовать как design+starter template.

# %%
stream_design = {
    "topic": "events.orders.v1",
    "key": "order_id",
    "bronze_table": "local.db.events_bronze",
    "silver_table": "local.db.events_silver",
}
stream_design

# %% [markdown]
# ## Task A - Event schema

# %%
example_event = {
    "event_id": "TODO",
    "event_ts": "TODO",
    "user_id": "TODO",
    "event_type": "TODO",
    "amount": "TODO",
}
example_event

# %% [markdown]
# ## Task B - Streaming read

# %%
# TODO: добавь spark.readStream.format('kafka')...
# TODO: распарси value как JSON и выдели нужные поля

# %% [markdown]
# ## Task C - Write curated output

# %%
# TODO: запиши поток в Bronze или Silver слой
# TODO: предложи проверки fresh data / duplicate ids / volume by batch
