# %% [markdown]
# # 03 - Airflow basic
#
# Цель: собрать простой DAG и понять, как читать логи и статусы в Airflow UI.

# %%
airflow_urls = {
    "web": "http://localhost:8083",
    "default_login": "airflow / airflow",
}
airflow_urls

# %% [markdown]
# ## Task A - DAG skeleton

# %%
# TODO: создай DAG с start_date, schedule и catchup=False
# TODO: добавь EmptyOperator и PythonOperator

# %% [markdown]
# ## Task B - Dependencies and retries

# %%
# TODO: задай retries=1 и retry_delay
# TODO: свяжи start >> main_task >> finish

# %% [markdown]
# ## Task C - UI review

# %%
ui_checklist = {
    "grid_view": "TODO",
    "logs": "TODO",
    "dag_run_status": "TODO",
    "retry_behavior": "TODO",
}
ui_checklist
