# %% [markdown]
# # 07 - Airflow with Spark batch pipelines
#
# Цель: разобрать и усилить batch pipeline из Airflow и Spark job'ов.

# %%
artifacts = {
    "dag": "airflow/dags/etl_dag.py",
    "spark_jobs": [
        "airflow/spark/currency_rates_raw.py",
        "airflow/spark/currency_rates_ods.py",
        "airflow/spark/dm_currency_rates_ods.py",
        "airflow/spark/load_to_pg.py",
    ],
}
artifacts

# %% [markdown]
# ## Task A - Map the pipeline

# %%
pipeline_map = {
    "raw": "TODO",
    "ods": "TODO",
    "dm": "TODO",
    "load_to_pg": "TODO",
}
pipeline_map

# %% [markdown]
# ## Task B - DAG review

# %%
# TODO: выпиши task_id, application, conf и зависимости для каждой стадии

# %% [markdown]
# ## Task C - Validation

# %%
validation_checks = [
    "TODO: row count в целевой таблице",
    "TODO: check на непустой dm-слой",
    "TODO: статусы задач в Airflow UI",
]
validation_checks
