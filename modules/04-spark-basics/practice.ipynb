# %% [markdown]
# # 04 - Spark basics
#
# Цель: пройти базовый сценарий `read -> transform -> write` в Spark DataFrame API.

# %%
from pyspark.sql import SparkSession, functions as F

DATASET_BASE = "/workspace/dataset"
ORDERS_PATH = f"{DATASET_BASE}/orders.csv"
PRODUCTS_PATH = f"{DATASET_BASE}/products.json"
OUTPUT_PATH = "file:///workspace/output/lesson04_sales_by_category"

# %% [markdown]
# ## Task A - Read data

# %%
# TODO: создай SparkSession
# TODO: прочитай orders.csv и products.json
# TODO: покажи printSchema() и show(5)

# %% [markdown]
# ## Task B - Transform data

# %%
# TODO: join orders с products по product_id
# TODO: посчитай выручку по category

# %% [markdown]
# ## Task C - Write result

# %%
# TODO: запиши результат в Parquet и перечитай его обратно

# %%
reflection = {
    "transformations": "TODO",
    "actions": "TODO",
    "why_parquet": "TODO",
}
reflection
